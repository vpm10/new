# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('housing.csv')

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
##for ploting

# %%
data.hist(bins=50,figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
#need to split the data into train set and test set

# %%
train_set,test_set = train_test_split(data,test_size=0.2,random_state=1)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15961    -122.43     37.71                52.0       1410.0           286.0
# 1771     -122.35     37.95                42.0       1485.0           290.0
# 16414    -121.24     37.90                16.0         50.0            10.0
# 5056     -118.35     34.02                34.0       5218.0          1576.0
# 8589     -118.39     33.89                38.0       1851.0           332.0
# ...          ...       ...                 ...          ...             ...
# 10955    -117.88     33.76                17.0       1768.0           474.0
# 17289    -119.63     34.42                42.0       1765.0           263.0
# 5192     -118.26     33.93                42.0       1433.0           295.0
# 12172    -117.16     33.73                10.0       2381.0           454.0
# 235      -122.20     37.79                35.0       1802.0           459.0
#
#        population  households  median_income  median_house_value  \
# 15961       879.0       282.0         3.1908            255600.0
# 1771        971.0       303.0         3.6094            114600.0
# 16414        20.0         6.0         2.6250            137500.0
# 5056       3538.0      1371.0         1.5143            118800.0
# 8589        750.0       314.0         7.3356            422700.0
# ...           ...         ...            ...                 ...
# 10955      1079.0       436.0         1.7823            205300.0
# 17289       753.0       260.0         8.5608            500001.0
# 5192        775.0       293.0         1.1326            104800.0
# 12172      1323.0       477.0         2.6322            140700.0
# 235        1009.0       390.0         2.3036            126000.0
#
#       ocean_proximity
# 15961        NEAR BAY
# 1771         NEAR BAY
# 16414          INLAND
# 5056        <1H OCEAN
# 8589        <1H OCEAN
# ...               ...
# 10955       <1H OCEAN
# 17289       <1H OCEAN
# 5192        <1H OCEAN
# 12172          INLAND
# 235          NEAR BAY
#
# [16512 rows x 10 columns]

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4712     -118.36     34.06                39.0       2810.0           670.0
# 2151     -119.78     36.78                37.0       2185.0           455.0
# 15927    -122.42     37.73                46.0       1819.0           411.0
# 82       -122.28     37.81                52.0        340.0            97.0
# 8161     -118.13     33.82                37.0       1530.0           290.0
# ...          ...       ...                 ...          ...             ...
# 2319     -119.70     36.82                25.0       2379.0           540.0
# 5341     -118.44     34.04                49.0         32.0             7.0
# 16888    -122.37     37.60                26.0         15.0             3.0
# 6823     -118.10     34.09                42.0       1460.0           289.0
# 11878    -117.38     33.99                52.0       1797.0           332.0
#
#        population  households  median_income  median_house_value  \
# 4712       1109.0       624.0         3.2500            355000.0
# 2151       1143.0       438.0         1.9784             70700.0
# 15927      1534.0       406.0         4.0132            229400.0
# 82          200.0        87.0         1.5208            112500.0
# 8161        711.0       283.0         5.1795            225400.0
# ...           ...         ...            ...                 ...
# 2319       1482.0       484.0         2.3173             68200.0
# 5341         14.0         7.0         2.1875            225000.0
# 16888        11.0         3.0         5.0480            350000.0
# 6823        829.0       273.0         4.8750            227300.0
# 11878       905.0       313.0         2.7054            141700.0
#
#       ocean_proximity
# 4712        <1H OCEAN
# 2151           INLAND
# 15927        NEAR BAY
# 82           NEAR BAY
# 8161        <1H OCEAN
# ...               ...
# 2319           INLAND
# 5341        <1H OCEAN
# 16888      NEAR OCEAN
# 6823        <1H OCEAN
# 11878          INLAND
#
# [4128 rows x 10 columns]

# %%
train_set.shape
# Out:
# (16512, 10)

# %%
test_set.shape
# Out:
# (4128, 10)

# %%
house = data.copy() #taking the copy of the data

# %%
house['income_cat'] = np.ceil(house['median_income']/1.5)

# %%
house['income_cat'].value_counts()
# Out:
# 3.0     7236
# 2.0     6581
# 4.0     3639
# 5.0     1423
# 1.0      822
# 6.0      532
# 7.0      189
# 8.0      105
# 9.0       50
# 11.0      49
# 10.0      14
# Name: income_cat, dtype: int64

# %%
house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    income_cat
# 0         6.0
# 1         6.0
# 2         5.0
# 3         4.0
# 4         3.0

# %%
house['income_cat'].where(house['income_cat']<5,5.0,inplace = True)

# %%
house['income_cat'].value_counts()
# Out:
# 3.0    7236
# 2.0    6581
# 4.0    3639
# 5.0    2362
# 1.0     822
# Name: income_cat, dtype: int64

# %%
sns.set_style('darkgrid')

# %%
house.income_cat.hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=1)

# %%
split
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=1, test_size=0.2,
#             train_size=None)

# %%
for train_index,test_index in split.split(house,house['income_cat']):
    strat_train_set = house.loc[train_index]
    strat_test_set = house.loc[test_index]

# %%
#drop income_cat
for set_ in (strat_test_set,strat_train_set):
    set_.drop('income_cat',axis=1,inplace=True)

# %%
(strat_train_set)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 740      -122.13     37.67                40.0       1748.0           318.0
# 19529    -120.98     37.65                40.0        422.0            63.0
# 8613     -118.37     33.87                23.0       1829.0           331.0
# 10142    -117.89     33.90                23.0       1533.0           226.0
# 15867    -122.40     37.76                52.0       1529.0           385.0
# ...          ...       ...                 ...          ...             ...
# 11207    -117.92     33.83                52.0       1514.0           301.0
# 9035     -117.84     34.63                 5.0       6739.0          1251.0
# 10482    -117.69     33.58                 5.0       6678.0          1011.0
# 13596    -117.30     34.10                49.0         60.0            11.0
# 1318     -121.77     37.99                 4.0       5623.0           780.0
#
#        population  households  median_income  median_house_value  \
# 740         914.0       317.0         3.8676            184000.0
# 19529       158.0        63.0         7.3841            172200.0
# 8613        891.0       356.0         6.5755            359900.0
# 10142       693.0       230.0         7.8980            258200.0
# 15867      1347.0       348.0         2.9312            239100.0
# ...           ...         ...            ...                 ...
# 11207       855.0       293.0         3.6042            166400.0
# 9035       4614.0      1266.0         4.0020            115100.0
# 10482      2877.0       982.0         7.5177            330000.0
# 13596        76.0        13.0         2.5625             75000.0
# 1318       2429.0       716.0         5.4409            205100.0
#
#       ocean_proximity
# 740          NEAR BAY
# 19529          INLAND
# 8613        <1H OCEAN
# 10142       <1H OCEAN
# 15867        NEAR BAY
# ...               ...
# 11207       <1H OCEAN
# 9035           INLAND
# 10482       <1H OCEAN
# 13596          INLAND
# 1318           INLAND
#
# [16512 rows x 10 columns]

# %% [markdown]
# Data Exploration

# %%
housing = strat_train_set.copy()

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 740      -122.13     37.67                40.0       1748.0           318.0
# 19529    -120.98     37.65                40.0        422.0            63.0
# 8613     -118.37     33.87                23.0       1829.0           331.0
# 10142    -117.89     33.90                23.0       1533.0           226.0
# 15867    -122.40     37.76                52.0       1529.0           385.0
#
#        population  households  median_income  median_house_value  \
# 740         914.0       317.0         3.8676            184000.0
# 19529       158.0        63.0         7.3841            172200.0
# 8613        891.0       356.0         6.5755            359900.0
# 10142       693.0       230.0         7.8980            258200.0
# 15867      1347.0       348.0         2.9312            239100.0
#
#       ocean_proximity
# 740          NEAR BAY
# 19529          INLAND
# 8613        <1H OCEAN
# 10142       <1H OCEAN
# 15867        NEAR BAY

# %%
housing.shape
# Out:
# (16512, 10)

# %% [markdown]
# Visualization

# %%
plt.rcParams['figure.figsize'] = (12,10)

# %%
housing.plot(kind='scatter',x='longitude',y='latitude',alpha=0.4)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind='scatter',x='longitude',y='latitude',alpha=0.4,s=housing['population']/100,label='population',c='median_house_value',cmap=plt.get_cmap('jet'),colorbar=True)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
corr_matrix= housing.corr()

# %%
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924134           -0.111588     0.044415
# latitude            -0.924134  1.000000            0.015882    -0.034892
# housing_median_age  -0.111588  0.015882            1.000000    -0.361921
# total_rooms          0.044415 -0.034892           -0.361921     1.000000
# total_bedrooms       0.070146 -0.066266           -0.321678     0.929588
# population           0.100851 -0.107384           -0.301220     0.859194
# households           0.055818 -0.069504           -0.305833     0.917847
# median_income       -0.013672 -0.082153           -0.115020     0.198109
# median_house_value  -0.043824 -0.146748            0.107684     0.133566
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070146    0.100851    0.055818      -0.013672
# latitude                 -0.066266   -0.107384   -0.069504      -0.082153
# housing_median_age       -0.321678   -0.301220   -0.305833      -0.115020
# total_rooms               0.929588    0.859194    0.917847       0.198109
# total_bedrooms            1.000000    0.878086    0.979825      -0.007167
# population                0.878086    1.000000    0.907188       0.008148
# households                0.979825    0.907188    1.000000       0.013529
# median_income            -0.007167    0.008148    0.013529       1.000000
# median_house_value        0.049941   -0.025008    0.065778       0.684828
#
#                     median_house_value
# longitude                    -0.043824
# latitude                     -0.146748
# housing_median_age            0.107684
# total_rooms                   0.133566
# total_bedrooms                0.049941
# population                   -0.025008
# households                    0.065778
# median_income                 0.684828
# median_house_value            1.000000

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.684828
# total_rooms           0.133566
# housing_median_age    0.107684
# households            0.065778
# total_bedrooms        0.049941
# population           -0.025008
# longitude            -0.043824
# latitude             -0.146748
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = [
    'median_house_value',
    'median_income',
    'total_rooms',
    'housing_median_age'
]

# %%
scatter_matrix(housing[attributes],figsize=(15,10))
plt.show()

# %%
housing.plot(kind='scatter',x='median_income',y='median_house_value',alpha=0.1)
plt.show()

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 740      -122.13     37.67                40.0       1748.0           318.0
# 19529    -120.98     37.65                40.0        422.0            63.0
# 8613     -118.37     33.87                23.0       1829.0           331.0
# 10142    -117.89     33.90                23.0       1533.0           226.0
# 15867    -122.40     37.76                52.0       1529.0           385.0
#
#        population  households  median_income  median_house_value  \
# 740         914.0       317.0         3.8676            184000.0
# 19529       158.0        63.0         7.3841            172200.0
# 8613        891.0       356.0         6.5755            359900.0
# 10142       693.0       230.0         7.8980            258200.0
# 15867      1347.0       348.0         2.9312            239100.0
#
#       ocean_proximity
# 740          NEAR BAY
# 19529          INLAND
# 8613        <1H OCEAN
# 10142       <1H OCEAN
# 15867        NEAR BAY

# %%
housing['rooms_per_hh'] = housing['total_rooms']/housing['households']
housing['bedrooms_per_room'] = housing['total_bedrooms']/housing['total_rooms']
housing['populatin_per_hh'] = housing['population']/housing['households']

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 740      -122.13     37.67                40.0       1748.0           318.0
# 19529    -120.98     37.65                40.0        422.0            63.0
# 8613     -118.37     33.87                23.0       1829.0           331.0
# 10142    -117.89     33.90                23.0       1533.0           226.0
# 15867    -122.40     37.76                52.0       1529.0           385.0
#
#        population  households  median_income  median_house_value  \
# 740         914.0       317.0         3.8676            184000.0
# 19529       158.0        63.0         7.3841            172200.0
# 8613        891.0       356.0         6.5755            359900.0
# 10142       693.0       230.0         7.8980            258200.0
# 15867      1347.0       348.0         2.9312            239100.0
#
#       ocean_proximity  rooms_per_hh  bedrooms_per_room  populatin_per_hh
# 740          NEAR BAY      5.514196           0.181922          2.883281
# 19529          INLAND      6.698413           0.149289          2.507937
# 8613        <1H OCEAN      5.137640           0.180973          2.502809
# 10142       <1H OCEAN      6.665217           0.147423          3.013043
# 15867        NEAR BAY      4.393678           0.251799          3.870690

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.684828
# rooms_per_hh          0.171947
# total_rooms           0.133566
# housing_median_age    0.107684
# households            0.065778
# total_bedrooms        0.049941
# population           -0.025008
# populatin_per_hh     -0.026596
# longitude            -0.043824
# latitude             -0.146748
# bedrooms_per_room    -0.256396
# Name: median_house_value, dtype: float64
